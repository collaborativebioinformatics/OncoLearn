# %% [markdown]
# ### Preturbation file format
# Explore the format of the preturbation files used by PerturbationDataModule

# %%
import scanpy as sc
# Out:
# /dccstor/bmfm-targets1/users/sivanra/miniforge/miniforge/envs/targets072025/lib/python3.11/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
#This was used in train and test of Norman datasets
norman_filename = "/dccstor/bmfm-targets/data/omics/transcriptome/scRNA/finetune/Perturbation/GEARS/norman_scgpt_split.h5ad"

# %%
adata = sc.read_h5ad(norman_filename)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 89357 × 5045
#     obs: 'condition', 'cell_type', 'dose_val', 'control', 'condition_name', 'scgpt_split'
#     var: 'gene_name'
#     uns: 'non_dropout_gene_idx', 'non_zeros_gene_idx', 'rank_genes_groups_cov_all', 'top_non_dropout_de_20', 'top_non_zero_de_20'
#     layers: 'counts'

# %%
adata.obs.columns
# Out:
# Index(['condition', 'cell_type', 'dose_val', 'control', 'condition_name',
#        'scgpt_split'],
#       dtype='object')

# %%
adata.obs["scgpt_split"].value_counts()
# Out:
# scgpt_split
# train    49849
# test     28754
# dev      10754
# Name: count, dtype: int64

# %%
adata.obs["condition"].value_counts()
# Out:
# condition
# ctrl             7353
# CEBPE+RUNX1T1    1030
# KLF1+ctrl         997
# TBX3+TBX2         969
# SLC4A1+ctrl       853
#                  ...
# PLK4+STIL          66
# SAMD1+TGFBR2       59
# JUN+CEBPB          52
# CBL+UBASH3A        50
# C3orf72+FOXL2      49
# Name: count, Length: 277, dtype: int64

# %%
adata.obs["condition_name"].value_counts()
# Out:
# condition_name
# A549_ctrl_1               7353
# A549_CEBPE+RUNX1T1_1+1    1030
# A549_KLF1+ctrl_1+1         997
# A549_TBX3+TBX2_1+1         969
# A549_SLC4A1+ctrl_1+1       853
#                           ...
# A549_PLK4+STIL_1+1          66
# A549_SAMD1+TGFBR2_1+1       59
# A549_JUN+CEBPB_1+1          52
# A549_CBL+UBASH3A_1+1        50
# A549_C3orf72+FOXL2_1+1      49
# Name: count, Length: 277, dtype: int64

# %%
adata.obs["dose_val"].value_counts()
# Out:
# dose_val
# 1+1    82004
# 1       7353
# Name: count, dtype: int64

# %%
adata.obs["control"].value_counts()
# Out:
# control
# 0    82004
# 1     7353
# Name: count, dtype: int64

# %%
norman_processed_filename = "/dccstor/bmfm-targets/data/omics/transcriptome/scRNA/finetune/Perturbation/GEARS/norman_scgpt_split_procesed.h5ad"

# %%
processed_adata = sc.read_h5ad(norman_processed_filename)
processed_adata
# Out:
# AnnData object with n_obs × n_vars = 89091 × 5045
#     obs: 'condition', 'cell_type', 'dose_val', 'control', 'condition_name', 'scgpt_split', 'split_stratified_None'
#     var: 'gene_name'
#     uns: 'non_dropout_gene_idx', 'non_zeros_gene_idx', 'rank_genes_groups', 'rank_genes_groups_cov_all', 'top_non_dropout_de_20', 'top_non_zero_de_20'
#     layers: 'counts'

# %% [markdown]
# condition values after cleaning which happened in the transfomers:

# %%
processed_adata.obs["condition"].value_counts()
# Out:
# condition
# Control         7353
# KLF1            1641
# BAK1            1171
# CEBPE           1039
# ETS2            1031
#                 ...
# CEBPA_JUN         70
# PLK4_STIL         66
# SAMD1_TGFBR2      59
# CEBPB_JUN         52
# CBL_UBASH3A       50
# Name: count, Length: 229, dtype: int64

# %%
processed_adata.obs["scgpt_split"].value_counts()
# Out:
# scgpt_split
# train    49849
# test     28488
# dev      10754
# Name: count, dtype: int64

# %%
processed_adata.obs["control"].value_counts()
# Out:
# control
# 0    81738
# 1     7353
# Name: count, dtype: int64

# %%
processed_adata[processed_adata.obs["scgpt_split"]=="train"].obs["condition"].value_counts()
# Out:
# condition
# Control          7353
# BAK1             1171
# CEBPE            1039
# ETS2             1031
# CEBPE_RUNX1T1    1030
#                  ...
# IGDCC3_ZBTB25      99
# PLK4               97
# KIF18B_KIF2C       83
# PLK4_STIL          66
# SAMD1_TGFBR2       59
# Name: count, Length: 108, dtype: int64

# %%
processed_adata[processed_adata.obs["scgpt_split"]=="test"].obs["condition"].value_counts()
# Out:
# condition
# TBX2_TBX3      969
# OSR2           858
# SLC4A1         853
# CNN1_ETS2      785
# DUSP9_ETS2     698
#               ...
# CEBPA_CEBPB     75
# DLX2_ZBTB10     74
# CEBPA_JUN       70
# CEBPB_JUN       52
# CBL_UBASH3A     50
# Name: count, Length: 95, dtype: int64

# %%
processed_adata[processed_adata.obs["scgpt_split"]=="dev"].obs["condition"].value_counts()
# Out:
# condition
# KLF1               1641
# ELMSAN1             783
# C19orf26            750
# ZBTB1               602
# TBX2                564
# ELMSAN1_LHX1        547
# KLF1_SET            541
# ELMSAN1_MAP2K3      484
# ARRDC3              405
# CNNM4               376
# ELMSAN1_MAP2K6      365
# BAK1_KLF1           323
# CEBPA_KLF1          308
# FOSB_PTPN12         291
# SGK1_TBX2           287
# BPGM_ZBTB1          283
# ETS2_TGFBR2         275
# C19orf26_TGFBR2     274
# ETS2_MAP7D1         265
# KLF1_TGFBR2         263
# KLF1_MAP2K6         222
# CLDN6_KLF1          215
# FOSB_IKZF3          204
# CITED1              169
# SAMD1_ZBTB1         164
# CBFA2T3_FEV         153
# Name: count, dtype: int64

# %% [markdown]
# Control cells can be only one the test, as they are identified by their perturbation name and added to all splits. see BasePerturbationDataset code
